# %% [markdown]
# # Pandas - explode()

# %%
# Importing Libraries
import ast
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# Load Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df = df.dropna(subset=['job_skills']).reset_index(drop=True)

# %%
df[['job_title_short', 'job_skills']].head(5)
# Out:
#   job_title_short                                         job_skills
# 0    Data Analyst         [r, python, sql, nosql, power bi, tableau]
# 1   Data Engineer  [python, sql, c#, azure, airflow, dax, docker,...
# 2   Data Engineer  [python, c++, java, matlab, aws, tensorflow, k...
# 3   Data Engineer  [bash, python, oracle, aws, ansible, puppet, j...
# 4   Data Engineer                                 [python, sql, gcp]

# %%
help(df.explode)
# Out:
# Help on method explode in module pandas.core.frame:
#
# explode(column: 'IndexLabel', ignore_index: 'bool' = False) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Transform each element of a list-like to a row, replicating index values.
#
#     Parameters
#     ----------
#     column : IndexLabel
#         Column(s) to explode.
#         For multiple columns, specify a non-empty list with each element
#         be str or tuple, and all specified columns their list-like data
#         on same row of the frame must have matching length.
#
#         .. versionadded:: 1.3.0
#             Multi-column explode
#
#     ignore_index : bool, default False
#         If True, the resulting index will be labeled 0, 1, …, n - 1.
#
#     Returns
#     -------
#     DataFrame
#         Exploded lists to rows of the subset columns;
#         index will be duplicated for these rows.
#
#     Raises
#     ------
#     ValueError :
#         * If columns of the frame are not unique.
#         * If specified columns to explode is empty list.
#         * If specified columns to explode have not matching count of
#           elements rowwise in the frame.
#
#     See Also
#     --------
#     DataFrame.unstack : Pivot a level of the (necessarily hierarchical)
#         index labels.
#     DataFrame.melt : Unpivot a DataFrame from wide format to long format.
#     Series.explode : Explode a DataFrame from list-like columns to long format.
#
#     Notes
#     -----
#     This routine will explode list-likes including lists, tuples, sets,
#     Series, and np.ndarray. The result dtype of the subset rows will
#     be object. Scalars will be returned unchanged, and empty list-likes will
#     result in a np.nan for that row. In addition, the ordering of rows in the
#     output will be non-deterministic when exploding sets.
#
#     Reference :ref:`the user guide <reshaping.explode>` for more examples.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'A': [[0, 1, 2], 'foo', [], [3, 4]],
#     ...                    'B': 1,
#     ...                    'C': [['a', 'b', 'c'], np.nan, [], ['d', 'e']]})
#     >>> df
#                A  B          C
#     0  [0, 1, 2]  1  [a, b, c]
#     1        foo  1        NaN
#     2         []  1         []
#     3     [3, 4]  1     [d, e]
#
#     Single-column explode.
#
#     >>> df.explode('A')
#          A  B          C
#     0    0  1  [a, b, c]
#     0    1  1  [a, b, c]
#     0    2  1  [a, b, c]
#     1  foo  1        NaN
#     2  NaN  1         []
#     3    3  1     [d, e]
#     3    4  1     [d, e]
#
#     Multi-column explode.
#
#     >>> df.explode(list('AC'))
#          A  B    C
#     0    0  1    a
#     0    1  1    b
#     0    2  1    c
#     1  foo  1  NaN
#     2  NaN  1  NaN
#     3    3  1    d
#     3    4  1    e

# %%
df_exploded = df.explode('job_skills')

# %%
df_exploded
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 0            Data Analyst                                       Data Analyst
# 0            Data Analyst                                       Data Analyst
# 0            Data Analyst                                       Data Analyst
# 0            Data Analyst                                       Data Analyst
# ...                   ...                                                ...
# 668702      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 668702      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 668702      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 668703  Software Engineer                                 AWS System Analyst
# 668703  Software Engineer                                 AWS System Analyst
#
#                                job_location              job_via  \
# 0              Guadalajara, Jalisco, Mexico     via BeBee México
# 0              Guadalajara, Jalisco, Mexico     via BeBee México
# 0              Guadalajara, Jalisco, Mexico     via BeBee México
# 0              Guadalajara, Jalisco, Mexico     via BeBee México
# 0              Guadalajara, Jalisco, Mexico     via BeBee México
# ...                                     ...                  ...
# 668702  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 668702  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 668702  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 668703                                India       melalui Trigyn
# 668703                                India       melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 0              Full-time               False          Mexico
# 0              Full-time               False          Mexico
# 0              Full-time               False          Mexico
# 0              Full-time               False          Mexico
# 0              Full-time               False          Mexico
# ...                  ...                 ...             ...
# 668702   Pekerjaan tetap               False           Sudan
# 668702   Pekerjaan tetap               False           Sudan
# 668702   Pekerjaan tetap               False           Sudan
# 668703   Pekerjaan tetap               False           India
# 668703   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-01-14 13:18:07                  False                 False
# 0      2023-01-14 13:18:07                  False                 False
# 0      2023-01-14 13:18:07                  False                 False
# 0      2023-01-14 13:18:07                  False                 False
# 0      2023-01-14 13:18:07                  False                 False
# ...                    ...                    ...                   ...
# 668702 2023-03-12 06:32:15                  False                 False
# 668702 2023-03-12 06:32:15                  False                 False
# 668702 2023-03-12 06:32:15                  False                 False
# 668703 2023-03-13 06:16:31                  False                 False
# 668703 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0           Mexico        None              NaN              NaN
# 0           Mexico        None              NaN              NaN
# 0           Mexico        None              NaN              NaN
# 0           Mexico        None              NaN              NaN
# 0           Mexico        None              NaN              NaN
# ...            ...         ...              ...              ...
# 668702       Sudan        None              NaN              NaN
# 668702       Sudan        None              NaN              NaN
# 668702       Sudan        None              NaN              NaN
# 668703       India        None              NaN              NaN
# 668703       India        None              NaN              NaN
#
#                       company_name  job_skills  \
# 0       Hewlett Packard Enterprise           r
# 0       Hewlett Packard Enterprise      python
# 0       Hewlett Packard Enterprise         sql
# 0       Hewlett Packard Enterprise       nosql
# 0       Hewlett Packard Enterprise    power bi
# ...                            ...         ...
# 668702                 Capital One       kafka
# 668702                 Capital One  kubernetes
# 668702                 Capital One      docker
# 668703                      Trigyn         aws
# 668703                      Trigyn        flow
#
#                                           job_type_skills
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# ...                                                   ...
# 668702  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 668702  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 668702  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 668703              {'cloud': ['aws'], 'other': ['flow']}
# 668703              {'cloud': ['aws'], 'other': ['flow']}
#
# [3660283 rows x 17 columns]

# %%
df_exploded['job_skills'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
skills_count = df_exploded.groupby(['job_title_short', 'job_skills']).size()

type(skills_count)
# Out:
# pandas.core.series.Series

# %%
df_skills_count = skills_count.reset_index(name='skill_count')

df_skills_count = df_skills_count.sort_values(by='skill_count', ascending=False)

df_skills_count
# Out:
#        job_title_short  job_skills  skill_count
# 1066    Data Scientist      python       113711
# 865      Data Engineer         sql       113130
# 830      Data Engineer      python       108022
# 625       Data Analyst         sql        92428
# 1101    Data Scientist         sql        78982
# ...                ...         ...          ...
# 462       Data Analyst     chainer            1
# 432     Cloud Engineer       wrike            1
# 410     Cloud Engineer      theano            1
# 24    Business Analyst     chainer            1
# 29    Business Analyst  codecommit            1
#
# [2256 rows x 3 columns]

# %%
job_title = "Data Engineer"
top_skills = 15

df_skill_final = df_skills_count[df_skills_count['job_title_short'] == job_title].head(top_skills)

df_skill_final.plot(kind='barh', x='job_skills', y='skill_count')

plt.gca().invert_yaxis()
plt.title(f'Top {top_skills} Skills for {job_title}')
plt.xlabel('Job Count')
plt.ylabel('')
plt.legend().set_visible(False)
plt.show()
